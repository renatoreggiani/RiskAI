# %%
import os
pwd_list = os.getcwd().split('\\')
if pwd_list[-1] != 'RiskAI' and 'RiskAI' in pwd_list:
    os.chdir('/'.join(pwd_list[:pwd_list.index('RiskAI')+1]))

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from ipywidgets import interact, fixed, FloatSlider, IntSlider
from preprocess import get_gsrai

# %%
df = pd.read_csv('dados/GSRAII.csv', parse_dates=['Date']).sort_values('Date')
df['year_week'] = df['Date'].dt.strftime('%Y-%U')
df['gsrai_dif'] = df['GSRAII Index'].diff()
df['max_week'] = df['GSRAII Index'].rolling(5).max()
df['min_week'] = df['GSRAII Index'].rolling(5).min()
df['std_week'] = df['GSRAII Index'].rolling(5).std()
df['best_diff_week'] = df['gsrai_dif'].rolling(5).max()
df['worst_diff_week'] = df['gsrai_dif'].rolling(5).min()
df = df.groupby('year_week').agg('last')

for n in range(1,6):
    df[f'diff_next_{n}_week'] = (df['GSRAII Index'].shift(n*-1).values - df['GSRAII Index'])
    
df
# Out:
#                 Date  GSRAII Index  gsrai_dif  max_week  min_week  std_week  \
# year_week
# 1997-00   1997-01-03          0.13       0.17       NaN       NaN       NaN
# 1997-01   1997-01-10          0.22       0.04      0.22      0.18  0.017321
# 1997-02   1997-01-17          0.36       0.13      0.36      0.23  0.055408
# 1997-03   1997-01-24          0.37       0.04      0.41      0.33  0.030332
# 1997-04   1997-01-31          0.29      -0.08      0.38      0.29  0.036332
# ...              ...           ...        ...       ...       ...       ...
# 2021-30   2021-07-30          0.11      -0.07      0.30      0.11  0.072595
# 2021-31   2021-08-06          0.31       0.07      0.31      0.09  0.088487
# 2021-32   2021-08-13          0.26      -0.09      0.37      0.26  0.042071
# 2021-33   2021-08-20         -0.09       0.02      0.19     -0.11  0.136492
# 2021-34   2021-08-25          0.16       0.08      0.16     -0.11  0.114586
#
#            best_diff_week  worst_diff_week  diff_next_1_week  \
# year_week
# 1997-00               NaN              NaN              0.09
# 1997-01              0.09            -0.04              0.14
# 1997-02              0.13            -0.07              0.01
# 1997-03              0.04            -0.08             -0.08
# 1997-04              0.03            -0.08             -0.07
# ...                   ...              ...               ...
# 2021-30              0.03            -0.15              0.20
# 2021-31              0.08            -0.02             -0.05
# 2021-32              0.06            -0.09             -0.35
# 2021-33              0.02            -0.23              0.25
# 2021-34              0.10            -0.23               NaN
#
#            diff_next_2_week  diff_next_3_week  diff_next_4_week  \
# year_week
# 1997-00                0.23              0.24              0.16
# 1997-01                0.15              0.07              0.00
# 1997-02               -0.07             -0.14             -0.27
# 1997-03               -0.15             -0.28             -0.34
# 1997-04               -0.20             -0.26             -0.24
# ...                     ...               ...               ...
# 2021-30                0.15             -0.20              0.05
# 2021-31               -0.40             -0.15               NaN
# 2021-32               -0.10               NaN               NaN
# 2021-33                 NaN               NaN               NaN
# 2021-34                 NaN               NaN               NaN
#
#            diff_next_5_week
# year_week
# 1997-00                0.09
# 1997-01               -0.13
# 1997-02               -0.33
# 1997-03               -0.32
# 1997-04                0.01
# ...                     ...
# 2021-30                 NaN
# 2021-31                 NaN
# 2021-32                 NaN
# 2021-33                 NaN
# 2021-34                 NaN
#
# [1302 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 1997-00 to 2021-34
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              1302 non-null   datetime64[ns]
#  1   GSRAII Index      1302 non-null   float64
#  2   gsrai_dif         1302 non-null   float64
#  3   max_week          1301 non-null   float64
#  4   min_week          1301 non-null   float64
#  5   std_week          1301 non-null   float64
#  6   best_diff_week    1301 non-null   float64
#  7   worst_diff_week   1301 non-null   float64
#  8   diff_next_1_week  1301 non-null   float64
#  9   diff_next_2_week  1300 non-null   float64
#  10  diff_next_3_week  1299 non-null   float64
#  11  diff_next_4_week  1298 non-null   float64
#  12  diff_next_5_week  1297 non-null   float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 142.4+ KB

# %%
df
# Out:
#                 Date  GSRAII Index  gsrai_dif  max_week  min_week  std_week  \
# year_week
# 1997-00   1997-01-03          0.13       0.17       NaN       NaN       NaN
# 1997-01   1997-01-10          0.22       0.04      0.22      0.18  0.017321
# 1997-02   1997-01-17          0.36       0.13      0.36      0.23  0.055408
# 1997-03   1997-01-24          0.37       0.04      0.41      0.33  0.030332
# 1997-04   1997-01-31          0.29      -0.08      0.38      0.29  0.036332
# ...              ...           ...        ...       ...       ...       ...
# 2021-30   2021-07-30          0.11      -0.07      0.30      0.11  0.072595
# 2021-31   2021-08-06          0.31       0.07      0.31      0.09  0.088487
# 2021-32   2021-08-13          0.26      -0.09      0.37      0.26  0.042071
# 2021-33   2021-08-20         -0.09       0.02      0.19     -0.11  0.136492
# 2021-34   2021-08-25          0.16       0.08      0.16     -0.11  0.114586
#
#            best_diff_week  worst_diff_week  diff_next_1_week  \
# year_week
# 1997-00               NaN              NaN              0.09
# 1997-01              0.09            -0.04              0.14
# 1997-02              0.13            -0.07              0.01
# 1997-03              0.04            -0.08             -0.08
# 1997-04              0.03            -0.08             -0.07
# ...                   ...              ...               ...
# 2021-30              0.03            -0.15              0.20
# 2021-31              0.08            -0.02             -0.05
# 2021-32              0.06            -0.09             -0.35
# 2021-33              0.02            -0.23              0.25
# 2021-34              0.10            -0.23               NaN
#
#            diff_next_2_week  diff_next_3_week  diff_next_4_week  \
# year_week
# 1997-00                0.23              0.24              0.16
# 1997-01                0.15              0.07              0.00
# 1997-02               -0.07             -0.14             -0.27
# 1997-03               -0.15             -0.28             -0.34
# 1997-04               -0.20             -0.26             -0.24
# ...                     ...               ...               ...
# 2021-30                0.15             -0.20              0.05
# 2021-31               -0.40             -0.15               NaN
# 2021-32               -0.10               NaN               NaN
# 2021-33                 NaN               NaN               NaN
# 2021-34                 NaN               NaN               NaN
#
#            diff_next_5_week
# year_week
# 1997-00                0.09
# 1997-01               -0.13
# 1997-02               -0.33
# 1997-03               -0.32
# 1997-04                0.01
# ...                     ...
# 2021-30                 NaN
# 2021-31                 NaN
# 2021-32                 NaN
# 2021-33                 NaN
# 2021-34                 NaN
#
# [1302 rows x 13 columns]

# %%
df.corr()
# Out:
#                   GSRAII Index  gsrai_dif  max_week  min_week  std_week  \
# GSRAII Index          1.000000   0.065013  0.980508  0.984033 -0.398557
# gsrai_dif             0.065013   1.000000 -0.064753 -0.041834 -0.084895
# max_week              0.980508  -0.064753  1.000000  0.982581 -0.299903
# min_week              0.984033  -0.041834  0.982581  1.000000 -0.470481
# std_week             -0.398557  -0.084895 -0.299903 -0.470481  1.000000
# best_diff_week       -0.210459   0.340011 -0.273209 -0.326624  0.379958
# worst_diff_week       0.388635   0.298565  0.267872  0.351729 -0.528062
# diff_next_1_week     -0.173361   0.061430 -0.172849 -0.168973  0.059782
# diff_next_2_week     -0.235557   0.028352 -0.237926 -0.229399  0.053005
# diff_next_3_week     -0.285627  -0.014643 -0.278654 -0.276678  0.102028
# diff_next_4_week     -0.321937   0.013900 -0.317702 -0.316776  0.121079
# diff_next_5_week     -0.354804  -0.008179 -0.346282 -0.342789  0.116475
#
#                   best_diff_week  worst_diff_week  diff_next_1_week  \
# GSRAII Index           -0.210459         0.388635         -0.173361
# gsrai_dif               0.340011         0.298565          0.061430
# max_week               -0.273209         0.267872         -0.172849
# min_week               -0.326624         0.351729         -0.168973
# std_week                0.379958        -0.528062          0.059782
# best_diff_week          1.000000        -0.114779         -0.003999
# worst_diff_week        -0.114779         1.000000         -0.070957
# diff_next_1_week       -0.003999        -0.070957          1.000000
# diff_next_2_week        0.044703        -0.094335          0.678946
# diff_next_3_week        0.039532        -0.120265          0.566865
# diff_next_4_week        0.069352        -0.132100          0.466858
# diff_next_5_week        0.055912        -0.137608          0.424863
#
#                   diff_next_2_week  diff_next_3_week  diff_next_4_week  \
# GSRAII Index             -0.235557         -0.285627         -0.321937
# gsrai_dif                 0.028352         -0.014643          0.013900
# max_week                 -0.237926         -0.278654         -0.317702
# min_week                 -0.229399         -0.276678         -0.316776
# std_week                  0.053005          0.102028          0.121079
# best_diff_week            0.044703          0.039532          0.069352
# worst_diff_week          -0.094335         -0.120265         -0.132100
# diff_next_1_week          0.678946          0.566865          0.466858
# diff_next_2_week          1.000000          0.794949          0.683226
# diff_next_3_week          0.794949          1.000000          0.843458
# diff_next_4_week          0.683226          0.843458          1.000000
# diff_next_5_week          0.596809          0.749673          0.872900
#
#                   diff_next_5_week
# GSRAII Index             -0.354804
# gsrai_dif                -0.008179
# max_week                 -0.346282
# min_week                 -0.342789
# std_week                  0.116475
# best_diff_week            0.055912
# worst_diff_week          -0.137608
# diff_next_1_week          0.424863
# diff_next_2_week          0.596809
# diff_next_3_week          0.749673
# diff_next_4_week          0.872900
# diff_next_5_week          1.000000

# %%
fig = px.line(df.dropna(), x='Date', y=['GSRAII Index', 'gsrai_dif', 'std_week'])
fig.show()
# Out:
# <div>                            <div id="543dd543-ea18-4e50-a1a9-fa9930d29cb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("543dd543-ea18-4e50-a1a9-fa9930d29cb1")) {                    Plotly.newPlot(                        "543dd543-ea18-4e50-a1a9-fa9930d29cb1",                        [{"hovertemplate": "variable=GSRAII Index<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "GSRAII Index", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "GSRAII Index", "showlegend": true, "type": "scattergl", "x": ["1997-01-08T00:00:00", "1997-01-09T00:00:00", "1997-01-10T00:00:00", "1997-01-13T00:00:00", "1997-01-14T00:00:00", "1997-01-15T00:00:00", "1997-01-16T00:00:00", "1997-01-17T00:00:00", "1997-01-20T00:00:00", "1997-01-21T00:00:00", "1997-01-22T00:00:00", "1997-01-23T00:00:00", "1997-01-24T00:00:00", "1997-01-27T00:00:00", "1997-01-28T00:00:00", "1997-01-29T00:00:00", "1997-01-30T00:00:00", "1997-01-31T00:00:00", "1997-02-03T00:00:00", "1997-02-04T00:00:00", "1997-02-05T00:00:00", "1997-02-06T00:00:00", "1997-02-07T00:00:00", "1997-02-10T00:00:00", "1997-02-11T00:00:00", "1997-02-12T00:00:00", "1997-02-13T00:00:00", "1997-02-17T00:00:00", "1997-02-18T00:00:00", "1997-02-20T00:00:00", "1997-02-24T00:00:00", "1997-02-25T00:00:00", "1997-02-26T00:00:00", "1997-02-27T00:00:00", "1997-02-28T00:00:00", "1997-03-03T00:00:00", "1997-03-04T00:00:00", "1997-03-05T00:00:00", "1997-03-06T00:00:00", "1997-03-07T00:00:00", "1997-03-10T00:00:00", "1997-03-11T00:00:00", "1997-03-12T00:00:00", "1997-03-13T00:00:00", "1997-03-14T00:00:00", "1997-03-17T00:00:00", "1997-03-18T00:00:00", "1997-03-19T00:00:00", "1997-03-20T00:00:00", "1997-03-21T00:00:00", "1997-03-24T00:00:00", "1997-03-25T00:00:00", "1997-03-26T00:00:00", "1997-03-27T00:00:00", "1997-03-28T00:00:00", "1997-03-31T00:00:00", "1997-04-01T00:00:00", "1997-04-02T00:00:00", "1997-04-03T00:00:00", "1997-04-04T00:00:00", "1997-04-07T00:00:00", "1997-04-08T00:00:00", "1997-04-09T00:00:00", "1997-04-10T00:00:00", "1997-04-11T00:00:00", "1997-04-14T00:00:00", "1997-04-15T00:00:00", "1997-04-16T00:00:00", "1997-04-17T00:00:00", "1997-04-18T00:00:00", "1997-04-21T00:00:00", "1997-04-22T00:00:00", "1997-04-23T00:00:00", "1997-04-24T00:00:00", "1997-04-25T00:00:00", "1997-04-28T00:00:00", "1997-04-29T00:00:00", "1997-04-30T00:00:00", "1997-05-01T00:00:00", "1997-05-02T00:00:00", "1997-05-05T00:00:00", "1997-05-06T00:00:00", "1997-05-07T00:00:00", "1997-05-08T00:00:00", "1997-05-09T00:00:00", "1997-05-12T00:00:00", "1997-05-13T00:00:00", "1997-05-14T00:00:00", "1997-05-15T00:00:00", "1997-05-16T00:00:00", "1997-05-19T00:00:00", "1997-05-20T00:00:00", "1997-05-21T00:00:00", "1997-05-22T00:00:00", "1997-05-23T00:00:00", "1997-05-26T00:00:00", "1997-05-27T00:00:00", "1997-05-28T00:00:00", "1997-05-29T00:00:00", "1997-05-30T00:00:00", "1997-06-02T00:00:00", "1997-06-03T00:00:00", "1997-06-04T00:00:00", "1997-06-05T00:00:00", "1997-06-06T00:00:00", "1997-06-09T00:00:00", "1997-06-10T00:00:00", "1997-06-11T00:00:00", "1997-06-12T00:00:00", "1997-06-16T00:00:00", "1997-06-17T00:00:00", "1997-06-18T00:00:00", "1997-06-19T00:00:00", "1997-06-20T00:00:00", "1997-06-23T00:00:00", "1997-06-24T00:00:00", "1997-06-25T00:00:00", "1997-06-26T00:00:00", "1997-06-30T00:00:00", "1997-07-01T00:00:00", "1997-07-02T00:00:00", "1997-07-03T00:00:00", "1997-07-04T00:00:00", "1997-07-07T00:00:00", "1997-07-08T00:00:00", "1997-07-09T00:00:00", "1997-07-10T00:00:00", "1997-07-11T00:00:00", "1997-07-14T00:00:00", "1997-07-15T00:00:00", "1997-07-16T00:00:00", "1997-07-17T00:00:00", "1997-07-18T00:00:00", "1997-07-21T00:00:00", "1997-07-22T00:00:00", "1997-07-23T00:00:00", "1997-07-24T00:00:00", "1997-07-25T00:00:00", "1997-07-28T00:00:00", "1997-07-29T00:00:00" ...

# %%
from statsmodels.tsa.stattools import acf, pacf, adfuller
from statsmodels.graphics.tsaplots import plot_acf

lag_acf = acf(df['GSRAII Index'].dropna(), nlags=30)
lag_pacf = pacf(df['GSRAII Index'].dropna(), nlags=30)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:667: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(

# %%
plot_acf(lag_acf);

# %%
plot_acf(lag_pacf);

# %%
adfuller(df['GSRAII Index'].dropna())
# Out:
# (-5.947488636626582,
#  2.1866592158396202e-07,
#  1,
#  1300,
#  {'1%': -3.435390199468821,
#   '5%': -2.8637658312426035,
#   '10%': -2.567955046745562},
#  140.78950603573594)

# %%
#%% Semanal
df_gp = df.groupby('year_week').agg('last')

# %%
# SHIFT +
# for pct in range(1,6):
#     df_gp[f'pct_{pct}_sem'] = (df_gp['retorno acumulado']/df_gp['retorno acumulado'].shift(pct).values -1) * 100

# SHIFT -
for pct in range(1,6):
    df_gp[f'pct_{pct}_sem'] = (df_gp['retorno acumulado'].shift(pct*-1).values/
                           df_gp['retorno acumulado'] -1) * 100

# %%
def classe_gsrai(df, limit=0, diff=None, media_movel=3):
    
    df=df.copy()
    df['gsrai_diff'] = df['GSRAII Index'].diff()
    
    if not media_movel == None: 
        df['mean'] = df['GSRAII Index'].rolling(media_movel).mean()
        up_down = df['mean']
        df['gsrai_gt_up'] = np.where((df['GSRAII Index'] > up_down) & (df['GSRAII Index'] >= limit), 1, 0)
        df['gsrai_gt_down'] = np.where((df['GSRAII Index'] < up_down) & (df['GSRAII Index'] >= limit), 1, 0)
        df['gsrai_lt_up'] = np.where((df['GSRAII Index'] > up_down) & (df['GSRAII Index'] < limit), 1, 0)
        df['gsrai_lt_down'] = np.where((df['GSRAII Index'] < up_down) & (df['GSRAII Index'] < limit), 1, 0)
    elif not diff == None: 
        df['gsrai_gt_up'] = np.where((df['gsrai_diff'] >= diff) & (df['GSRAII Index'] >= limit), 1, 0)
        df['gsrai_gt_down'] = np.where((df['gsrai_diff'] < diff) & (df['GSRAII Index'] >= limit), 1, 0)
        df['gsrai_lt_up'] = np.where((df['gsrai_diff'] >= diff) & (df['GSRAII Index'] < limit), 1, 0)
        df['gsrai_lt_down'] = np.where((df['gsrai_diff'] < diff) & (df['GSRAII Index'] < limit), 1, 0)
        
        
    regras = ['gsrai_gt_up', 'gsrai_gt_down', 'gsrai_lt_up', 'gsrai_lt_down']
    df['classe'] = np.nan
    for col in regras:
        df.loc[df[col]==1, 'classe'] = col
    return df

# %%
df_gp =  classe_gsrai(df=df_gp, limit=0, media_movel=None, diff=0)
# df_gp['classe'] = df_gp['classe'].shift(-1).values
for col in ['pct_1_sem', 'pct_2_sem', 'pct_3_sem', 'pct_4_sem', 'pct_5_sem']:
    df_gp[col] = df_gp[col].shift(1).values

# %%
df_gp

# %%
pct =  'pct_1_sem'
regras = ['gsrai_gt_up', 'gsrai_gt_down', 'gsrai_lt_up', 'gsrai_lt_down']

# %%
lista = []
for col in df_gp['classe'].dropna().unique():
    desc = df_gp[df_gp[col]==1][[pct]].describe().rename(columns={pct: col})
    lista.append(desc)
pd.concat(lista, axis=1)

# %%
@interact(df=fixed(df_gp), 
          pct=['pct_1_sem', 'pct_2_sem', 'pct_3_sem', 'pct_4_sem', 'pct_5_sem'],
          limit=FloatSlider(min=-1, max=1, step=0.05, value=0),
          diff=FloatSlider(min=-1, max=1, step=0.05, value=0),
#           media_movel=IntSlider(min=2, max=6, step=1, value=3)
         )
def hist_classes(df, pct, limit=0, diff=0):
    df = classe_gsrai(df=df, limit=limit, media_movel=None, diff=diff).dropna()
    fig = px.histogram(df.sort_values('classe'), x=pct, color="classe", marginal="box", nbins=100, 
#                        range_y=[0,50],
                       range_x=[df[pct].min()-1,df[pct].max()+1],
                       title=f'Distribuição {indice} {pct} ',
                      )
    fig.update_layout(barmode='overlay')
    fig.update_traces(opacity=0.65)
    fig.add_vline(x=0,line_dash="dash")
    
    for i, classe in enumerate(df['classe'].unique()):
        fig.add_annotation(text=f'Total {classe}: {len(df[df["classe"]==classe])}',
                           showarrow=False, yshift=70-(i*19), xshift=450)
        fig.add_annotation(text=f'σ {classe}: {df[df["classe"]==classe][pct].std():.2f} ',
                       showarrow=False, yshift=200-(i*19), xshift=450)   
    return fig

    
hist_classes(df_gp, pct, limit=-1, diff=0);

# %%
@interact(df=fixed(df_gp), 
          pct=['pct_1_sem', 'pct_2_sem', 'pct_3_sem', 'pct_4_sem', 'pct_5_sem'],
          limit=FloatSlider(min=-1, max=1, step=0.05, value=0),
#           media_movel=IntSlider(min=2, max=6, step=1, value=3)
         )
def hist_diff(df, pct, limit=0):
    df = classe_gsrai(df=df, limit=limit, media_movel=3).dropna()
    df = df.copy()
    df['classe_diff'] = np.where(df['gsrai_diff']<=limit, 'abaixo', 'acima')
    fig = px.histogram(df.sort_values('classe_diff', ascending=False), 
                       x=pct, color="classe_diff", 
                       marginal="box", nbins=100, 
#                        range_y=[0,50],
                       range_x=[df[pct].min()-1,df[pct].max()+1],
                       title=f'Distribuição {indice} {pct} por diff GSRAI',
                      )
    fig.update_layout(barmode='overlay')
    fig.update_traces(opacity=0.65)
    fig.add_vline(x=0,line_dash="dash")
    
    for i, classe in enumerate(df['classe_diff'].unique()):
        fig.add_annotation(text=f'Total {classe}: {len(df[df["classe_diff"]==classe])}',
                           showarrow=False, yshift=100-(i*19), xshift=450)
        fig.add_annotation(text=f'σ {classe}: {df[df["classe_diff"]==classe][pct].std():.2f} ',
                       showarrow=False, yshift=200-(i*19), xshift=450)   
    return fig

    
hist_diff(df_gp, pct);

# %%
cut = df_gp[pct].quantile(0.15)
df_gp[(df_gp[pct]<=cut)].sum()

# %%
@interact(df=fixed(df_gp), 
          pct=['pct_1_sem', 'pct_2_sem', 'pct_3_sem', 'pct_4_sem', 'pct_5_sem'],
          limit=FloatSlider(min=-1, max=1, step=0.05, value=0),
#           diff=FloatSlider(min=-1, max=1, step=0.05, value=0),
          media_movel=IntSlider(min=2, max=6, step=1, value=3)
         )
def hist_classes(df, pct, limit=0, media_movel=3):
    df = classe_gsrai(df=df, limit=limit, media_movel=3, diff=None).dropna()
    fig = px.histogram(df.sort_values('classe'), x=pct, color="classe", marginal="box", nbins=100, 
#                        range_y=[0,50],
                       range_x=[df[pct].min()-1,df[pct].max()+1],
                       title=f'Distribuição {indice} {pct} ',
                      )
    fig.update_layout(barmode='overlay')
    fig.update_traces(opacity=0.65)
    fig.add_vline(x=0,line_dash="dash")
    
    for i, classe in enumerate(df['classe'].unique()):
        fig.add_annotation(text=f'Total {classe}: {len(df[df["classe"]==classe])}',
                           showarrow=False, yshift=70-(i*19), xshift=450)
        fig.add_annotation(text=f'σ {classe}: {df[df["classe"]==classe][pct].std():.2f} ',
                       showarrow=False, yshift=200-(i*19), xshift=450)   
    return fig

    
hist_classes(df_gp, pct, limit=-1, diff=0);

# %%
df_gp[(df_gp[pct]>cut) & (df_gp['gsrai_lt_down']==0)][pct].describe()

# %%
df_gp.columns

# %%
# import seaborn as sns
# sns.pairplot(df_gp.drop(columns= ['gsrai_gt_up',
#        'gsrai_gt_down', 'gsrai_lt_up', 'gsrai_lt_down']), hue='classe');

# %%
df_gp.to_csv('gsrai.csv')

# %%
df_gp['2019-35':'2019-45']

# %%
df_gp[(df_gp['pct_ret']<0) & (df_gp['gsrai_lt_down']==1)]['pct_ret'].describe()

# %%
df_gp[(df_gp['gsrai_lt_down']==1)]['pct_ret'].describe()

# %%
df_gp[(df_gp['gsrai_lt_down']==1)]['pct_ret_shift'].describe()

# %%
df['retorno acumulado'].plot()

# %%
#%% Grafico

fig = px.line(df, x="Date", y='retorno acumulado')
# mask = df_gp['gsrai_lt_down']==1
# fig = px.line(df_gp, x="Date", y=['GSRAII Index', 'pct_ret'])

# fig.add_trace(go.Scatter(
#     x=df_gp[mask]['Date'],
#     y=df_gp[mask][pct],
#     marker_size=10, mode='markers', name='Queda',
#     ))

fig.show()

# %%
df_gp

# %%
from statsmodels.tsa.stattools import acf, pacf, adfuller
from statsmodels.graphics.tsaplots import plot_acf

lag_acf = acf(df['GSRAII Index'].dropna(), nlags=30)
lag_pacf = pacf(df['GSRAII Index'].dropna(), nlags=30)

# %%
plot_acf(lag_acf)

plot_acf(lag_pacf)

adfuller(df_gp['gsrai_diff'].dropna())

df_gp['pct_1_sem'].describe()

# %%
df_gp[df_gp['gsrai_diff']<-0.3]['pct_1_sem'].describe()

# %%
df_gp['2019:01':'2020:20']['gsrai_diff'].plot()

# %%
df
